# %% [markdown]
# # Fine-Tune Pretrained Transformer - Analysis
#
# ## Contents
# 1. BERT Fine-Tuning Results
# 2. Attention Pattern Analysis
# 3. From-Scratch vs Fine-Tuning Comparison
# 4. GPT-2 Text Generation
# 5. Comparative Written Analysis

# %%
import sys
sys.path.append('..')

import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import BertTokenizer, BertModel

from utils import plot_attention_heatmap, plot_confusion_matrix, plot_data_efficiency

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 6)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')

# %% [markdown]
# ## 1. BERT Fine-Tuning Results
#
# Load the fine-tuned model and report accuracy, F1, and confusion matrix.

# %%
# TODO: Load fine-tuned BERT and compute final metrics
# TODO: Plot training loss and validation accuracy curves
# TODO: Display confusion matrix

# %% [markdown]
# ## 2. Attention Pattern Analysis
#
# Extract and visualize attention weights from BERT.

# %%
# TODO: Pick 3 sentences and extract attention weights
# TODO: Visualize attention heatmaps across layers and heads
# TODO: Look for positional, separator, and syntactic patterns
# TODO: Implement and visualize attention rollout

# %% [markdown]
# ## 3. Data Efficiency Comparison

# %%
# TODO: Plot accuracy vs training data size for both BERT and from-scratch
# data_sizes = [100, 500, 1000, 5000, 'full']
# plot_data_efficiency(data_sizes, bert_accs, scratch_accs)

# %% [markdown]
# ## 4. GPT-2 Text Generation

# %%
# TODO: Generate text with greedy, temperature, top-k, and top-p sampling
# TODO: Compare coherence, diversity, and fluency across strategies

# %% [markdown]
# ## 5. Comparative Written Analysis
#
# 1. **The power of pretraining**: Why is fine-tuning so data-efficient?
# 2. **Encoder vs Decoder**: When to use BERT vs GPT?
# 3. **The fine-tuning recipe**: Rank the most important ingredients.
# 4. **Scaling intuition**: How would different model sizes compare?
# 5. **When NOT to fine-tune**: Describe a scenario where it is the wrong approach.
