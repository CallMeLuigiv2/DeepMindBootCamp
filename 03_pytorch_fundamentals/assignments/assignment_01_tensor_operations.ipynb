# %% [markdown]
# # Assignment 01: Tensor Operations — Mastery Through Repetition
#
# **Module:** 03 — PyTorch Fundamentals
# **Estimated Time:** 4-6 hours
#
# ---
#
# ## Learning Objectives
#
# - Create tensors fluently and inspect their properties (shape, dtype, device, stride)
# - Master broadcasting rules and predict output shapes without running code
# - Understand memory layout: strides, contiguity, view vs reshape, storage
# - Implement matrix multiplication using only element-wise ops and reduction
# - Benchmark GPU vs CPU operations

# %%
import sys
import time
import numpy as np
import torch

sys.path.insert(0, '../../')
from shared_utils.common import set_seed, get_device

set_seed(42)
device = get_device()
print(f'Using device: {device}')
print(f'PyTorch version: {torch.__version__}')
print('Setup complete.')

# %% [markdown]
# ---
# ## Part 1: Tensor Creation and Properties (20 min)
#
# Create each tensor and print its `shape`, `dtype`, `device`, and `stride()`.

# %%
def describe(t: torch.Tensor, name: str):
    """Print tensor properties."""
    print(f'{name}: shape={t.shape}, dtype={t.dtype}, device={t.device}, stride={t.stride()}')

# %%
# 1. 3x4 tensor of zeros (float32)
# YOUR CODE HERE

# 2. 5x5 identity matrix
# YOUR CODE HERE

# 3. 1D tensor of integers 0 to 99
# YOUR CODE HERE

# 4. 2x3x4 standard normal random
# YOUR CODE HERE

# 5. Tensor from Python list [[1,2],[3,4],[5,6]]
# YOUR CODE HERE

# 6. 50 evenly spaced values between -1 and 1
# YOUR CODE HERE

# 7. 4x4 ones on GPU (if available)
# YOUR CODE HERE

# 8. Same shape/device as #4, filled with 7
# YOUR CODE HERE

# 9. From NumPy array (verify shared memory)
# YOUR CODE HERE

# 10. Uninitialized 1000x1000 (explain why dangerous)
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 2: Predict the Shape (Broadcasting)
#
# For each pair, **write your predicted shape** as a comment, then verify.

# %%
# 1. Prediction: shape = ???
a = torch.randn(5, 3)
b = torch.randn(3)
# result = a + b
# print(result.shape)

# %%
# 2. Prediction: shape = ???
a = torch.randn(2, 1, 4)
b = torch.randn(3, 1)
# result = a + b
# print(result.shape)

# %%
# 3. Prediction: shape = ???
a = torch.randn(3, 1)
b = torch.randn(1, 4)
# result = a + b
# print(result.shape)

# %%
# 4. Prediction: shape = ???
a = torch.randn(2, 3, 4)
b = torch.randn(2, 1, 4)
# result = a + b
# print(result.shape)

# %%
# 5. Prediction: shape = ???
a = torch.randn(5, 3, 4, 1)
b = torch.randn(4, 2)
# result = a + b
# print(result.shape)

# %%
# 6. Prediction: shape = ??? or Error?
a = torch.randn(3, 4)
b = torch.randn(5, 4)
# result = a + b
# print(result.shape)

# %%
# 7. Prediction: shape = ???
a = torch.randn(1, 5, 1, 3)
b = torch.randn(2, 1, 4, 3)
# result = a + b
# print(result.shape)

# %%
# 8. Prediction: shape = ???
a = torch.randn(3, 1)
b = torch.randn(2, 1, 4)
# result = a + b
# print(result.shape)

# %%
# 9. Prediction: shape = ???
a = torch.randn(6, 1, 3)
b = torch.randn(1, 5, 1)
# result = a + b
# print(result.shape)

# %%
# 10. Prediction: shape = ??? or Error?
a = torch.randn(2, 3)
b = torch.randn(4, 3)
# result = a + b
# print(result.shape)

# %% [markdown]
# ---
# ## Part 3: Indexing and Slicing Challenges (30 min)
#
# Using `x = torch.arange(60).reshape(3, 4, 5)`, write one-line expressions.

# %%
x = torch.arange(60).reshape(3, 4, 5)

# 1. Element at [1, 2, 3] -> expected shape: scalar
# YOUR CODE HERE

# 2. First slice along dim 0 -> expected shape: (4, 5)
# YOUR CODE HERE

# 3. Last element along dim 2 for all -> expected shape: (3, 4)
# YOUR CODE HERE

# 4. Every other element along dim 2 -> expected shape: (3, 4, 3)
# YOUR CODE HERE

# 5. All elements where value > 40
# YOUR CODE HERE

# 6. All elements divisible by 7
# YOUR CODE HERE

# 7. Positions [0,2] along dim 0 and [1,3] along dim 1
# YOUR CODE HERE

# 8. Replace elements > 50 with -1
# YOUR CODE HERE

# 9. torch.where: replace negatives with 0
y = torch.randn(5, 5)
# YOUR CODE HERE

# 10. torch.gather along dim 1
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 4: Memory Layout Exercises (45 min)
#
# ### 4.1: Stride Investigation

# %%
x = torch.arange(24).reshape(2, 3, 4)

# 1. What is x.stride()? Explain each number.
print(f'x.stride() = {x.stride()}')
# YOUR EXPLANATION HERE

# 2. x.T: stride? contiguous?
print(f'x.T.stride() = {x.T.stride()}, contiguous = {x.T.is_contiguous()}')

# 3. permute(2, 0, 1): stride? contiguous?
y = x.permute(2, 0, 1)
print(f'y.stride() = {y.stride()}, contiguous = {y.is_contiguous()}')

# 4. x[:, ::2, :]: stride? contiguous?
z = x[:, ::2, :]
print(f'z.stride() = {z.stride()}, contiguous = {z.is_contiguous()}')

# 5. Call .contiguous() on each non-contiguous tensor and verify
# YOUR CODE HERE

# %% [markdown]
# ### 4.2: View vs Reshape
#
# Predict whether `.view()` works or errors.

# %%
# Prediction: works or error?
a = torch.arange(12).reshape(3, 4)
# a.view(4, 3)     # YOUR PREDICTION

# b = a.t()
# b.view(12)       # YOUR PREDICTION

# c = a[:, :2]
# c.view(6)        # YOUR PREDICTION

# d = torch.arange(12).reshape(3, 4).contiguous()
# d.view(2, 6)     # YOUR PREDICTION

# e = torch.arange(12).reshape(3, 4).permute(1, 0)
# e.reshape(12)    # YOUR PREDICTION

# %% [markdown]
# ### 4.3: Storage

# %%
x = torch.arange(12).reshape(3, 4)
y = x[1:3, 1:3]

# 1. Same storage?
print(f'Same storage: {x.storage().data_ptr() == y.storage().data_ptr()}')

# 2. y.storage_offset()?
print(f'y.storage_offset() = {y.storage_offset()}')
# YOUR EXPLANATION HERE

# 3. Modify y[0,0] = 999, check x
# YOUR CODE HERE

# 4. Clone z = y.clone(), modify z, check y
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 5: Manual Matrix Multiplication (30 min)

# %%
def manual_matmul(A: torch.Tensor, B: torch.Tensor) -> torch.Tensor:
    """Multiply A (m x n) and B (n x p) -> (m x p).
    Use only element-wise ops, broadcasting, and reduction.
    Do NOT use torch.mm, torch.matmul, @, or torch.einsum.

    Hint: A has shape (m, n), B has shape (n, p).
    Unsqueeze to (m, n, 1) and (1, n, p), multiply, sum over n.
    """
    assert A.dim() == 2 and B.dim() == 2, 'Inputs must be 2D'
    assert A.shape[1] == B.shape[0], f'Incompatible shapes: {A.shape} and {B.shape}'
    # YOUR CODE HERE
    pass

# %%
# --- Test Part 5 ---
A = torch.randn(3, 4)
B = torch.randn(4, 5)
result = manual_matmul(A, B)
expected = torch.mm(A, B)
assert torch.allclose(result, expected, atol=1e-5), 'manual_matmul failed!'

# Test more sizes
for m, n, p in [(10, 20, 3), (1, 5, 1), (100, 50, 30)]:
    A = torch.randn(m, n)
    B = torch.randn(n, p)
    assert torch.allclose(manual_matmul(A, B), torch.mm(A, B), atol=1e-4)

# Benchmark
A_big = torch.randn(1000, 1000)
B_big = torch.randn(1000, 1000)

start = time.time()
_ = manual_matmul(A_big, B_big)
manual_time = time.time() - start

start = time.time()
_ = torch.mm(A_big, B_big)
builtin_time = time.time() - start

print(f'manual_matmul: {manual_time*1000:.1f}ms')
print(f'torch.mm:      {builtin_time*1000:.1f}ms')
print(f'Speedup:       {manual_time/builtin_time:.0f}x')
print('Part 5 tests passed!')

# %% [markdown]
# ---
# ## Part 6: GPU vs CPU Benchmarking (30 min)
#
# *Skip if no CUDA GPU is available.*

# %%
if not torch.cuda.is_available():
    print('No CUDA GPU available. Skipping GPU benchmarks.')
else:
    def benchmark_op(op, *args, n_warmup=5, n_runs=20, use_cuda=False):
        """Benchmark an operation with proper GPU timing."""
        # Warmup
        for _ in range(n_warmup):
            op(*args)

        if use_cuda:
            torch.cuda.synchronize()
            start_event = torch.cuda.Event(enable_timing=True)
            end_event = torch.cuda.Event(enable_timing=True)
            start_event.record()
            for _ in range(n_runs):
                op(*args)
            end_event.record()
            torch.cuda.synchronize()
            return start_event.elapsed_time(end_event) / n_runs
        else:
            start = time.time()
            for _ in range(n_runs):
                op(*args)
            return (time.time() - start) / n_runs * 1000  # ms

    # YOUR CODE HERE: benchmark 4 operations on CPU and GPU
    # 1. Large matmul: (1000,1000) @ (1000,1000)
    # 2. Element-wise: torch.sin(x) for (10000,10000)
    # 3. Reduction: x.sum() for (10000,10000)
    # 4. Small matmul: (10,10) @ (10,10)
    # Print results as a table
    pass

# %% [markdown]
# ---
# ## Part 7: 20+ Operations Without Docs (45 min)
#
# Try each operation without looking at documentation. Mark any you struggle with.

# %%
# 1. Random 5x5, compute transpose
# YOUR CODE HERE

# 2. Element-wise product of two 3x4 tensors
# YOUR CODE HERE

# 3. Dot product of two 1D tensors (length 10)
# YOUR CODE HERE

# 4. Stack three 3x3 tensors along new dim 0 -> (3, 3, 3)
# YOUR CODE HERE

# 5. Concatenate three 3x3 along dim 1 -> (3, 9)
# YOUR CODE HERE

# 6. Mean and std along dim 1
# YOUR CODE HERE

# 7. Indices of max values along dim 0
# YOUR CODE HERE

# 8. Sort 2D tensor along dim 1
# YOUR CODE HERE

# 9. Clamp values to [-1, 1]
# YOUR CODE HERE

# 10. L2 norm of each row in 5x10 matrix
# YOUR CODE HERE

# 11. Diagonal matrix from 1D tensor
# YOUR CODE HERE

# %%
# 12. Element-wise absolute value
# YOUR CODE HERE

# 13. Boolean mask: select elements and sum
# YOUR CODE HERE

# 14. Repeat 2x3 tensor: 4x along dim 0, 2x along dim 1
# YOUR CODE HERE

# 15. Flatten 2x3x4 to 1D
# YOUR CODE HERE

# 16. Unsqueeze 1D(5) to (1, 5, 1)
# YOUR CODE HERE

# 17. Cumulative sum along dim 0 of 4x4
# YOUR CODE HERE

# 18. Unique elements and counts
# YOUR CODE HERE

# 19. Outer product without torch.outer
# YOUR CODE HERE

# 20. Lower triangular mask 5x5
# YOUR CODE HERE

# 21. Top-3 values and indices per row in 10x20
# YOUR CODE HERE

# 22. Batched matmul with einsum
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Lessons Learned
#
# - **Operations I found most confusing:**
#
# *YOUR NOTES HERE*
#
# - **Key insights about memory layout:**
#
# *YOUR NOTES HERE*
#
# - **Benchmarking surprises:**
#
# *YOUR NOTES HERE*
