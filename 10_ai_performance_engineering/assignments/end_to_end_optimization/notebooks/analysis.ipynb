# %% [markdown]
# # End-to-End Optimization - Analysis
#
# 1. Model architecture and memory budget
# 2. Baseline profiling
# 3. Per-technique optimization results
# 4. Waterfall chart and performance report

# %%
import sys
sys.path.insert(0, '..')

import torch
import matplotlib.pyplot as plt
import numpy as np

from utils import compute_memory_budget

# %% [markdown]
# ## Memory Budget Estimation

# %%
# Estimate memory budget for the Transformer model
budget = compute_memory_budget(
    num_params=15_000_000,  # ~15M
    batch_size=16,
    seq_length=256,
    hidden_dim=256,
    num_layers=6,
)
for k, v in budget.items():
    print(f'{k}: {v:.1f} MB')

# %% [markdown]
# ## Optimization Results

# %%
# TODO: Load benchmark results and create waterfall chart
# TODO: Create speedup attribution table
