# %% [markdown]
# # DQN Analysis Notebook
#
# Visualize training results, compare DQN variants, and analyze Q-value overestimation.
#
# ## Contents
# 1. Learning Curves: Naive vs Replay vs DQN vs Double DQN
# 2. Target Update Frequency Comparison
# 3. Q-Value Overestimation Analysis
# 4. LunarLander Training Metrics
# 5. Ablation Study Results

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import sys
sys.path.append('..')

from utils import EpisodeTracker, moving_average

# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## 1. CartPole-v1: Progressive DQN Comparison
#
# Compare Naive DQN, DQN with Replay, Full DQN, and Double DQN on CartPole-v1.
# This should clearly show the contribution of each component.

# %%
# Load training results (replace with your actual data)
# Example: results = torch.load('logs/cartpole_comparison.pt')

# Placeholder for plotting structure
fig, ax = plt.subplots(1, 1, figsize=(14, 7))

variants = ['Naive DQN', 'DQN + Replay', 'Full DQN', 'Double DQN']
colors = ['#e74c3c', '#f39c12', '#2ecc71', '#3498db']

# TODO: Load your actual reward histories and plot them
# for name, color in zip(variants, colors):
#     rewards = results[name].rewards
#     smoothed = moving_average(rewards, window=50)
#     ax.plot(smoothed, label=name, color=color, alpha=0.9)
#     ax.fill_between(range(len(rewards)), 
#                     moving_average(rewards, 50) - np.std(rewards[-50:]),
#                     moving_average(rewards, 50) + np.std(rewards[-50:]),
#                     alpha=0.15, color=color)

ax.set_xlabel('Episode')
ax.set_ylabel('Reward')
ax.set_title('CartPole-v1: Progressive DQN Improvements')
ax.legend(loc='lower right')
ax.axhline(y=475, color='gray', linestyle='--', alpha=0.5, label='Solved threshold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Target Update Frequency Comparison
#
# Compare target_update_freq = 10, 100, and 1000 on CartPole-v1.

# %%
fig, ax = plt.subplots(1, 1, figsize=(14, 7))

update_freqs = [10, 100, 1000]
colors = ['#e74c3c', '#2ecc71', '#3498db']

# TODO: Load and plot results for each target update frequency
# for freq, color in zip(update_freqs, colors):
#     rewards = results[f'target_freq_{freq}'].rewards
#     smoothed = moving_average(rewards, window=50)
#     ax.plot(smoothed, label=f'target_update_freq={freq}', color=color)

ax.set_xlabel('Episode')
ax.set_ylabel('Reward')
ax.set_title('Effect of Target Network Update Frequency')
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Q-Value Overestimation Analysis
#
# Compare predicted Q-values vs actual returns for standard DQN and Double DQN.
# Double DQN should show less overestimation.

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# TODO: Load Q-value analysis data
# Left plot: Standard DQN
# axes[0].plot(predicted_q_dqn, label='Predicted Q', color='#e74c3c')
# axes[0].plot(actual_returns_dqn, label='Actual Return', color='#2ecc71')
# axes[0].fill_between(range(len(predicted_q_dqn)),
#                      actual_returns_dqn, predicted_q_dqn,
#                      alpha=0.2, color='#e74c3c', label='Overestimation')
# axes[0].set_title('Standard DQN: Q-Value Overestimation')

# Right plot: Double DQN
# axes[1].plot(predicted_q_ddqn, label='Predicted Q', color='#e74c3c')
# axes[1].plot(actual_returns_ddqn, label='Actual Return', color='#2ecc71')
# axes[1].fill_between(range(len(predicted_q_ddqn)),
#                      actual_returns_ddqn, predicted_q_ddqn,
#                      alpha=0.2, color='#e74c3c', label='Overestimation')
# axes[1].set_title('Double DQN: Q-Value Overestimation')

for ax in axes:
    ax.set_xlabel('Training Step')
    ax.set_ylabel('Value')
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. LunarLander-v2 Training Metrics
#
# Full dashboard: reward, Q-values, buffer size, epsilon, and loss over training.

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# TODO: Load LunarLander training metrics and plot

# (0,0) Reward per episode
axes[0, 0].set_title('Episode Reward')
axes[0, 0].set_xlabel('Episode')
axes[0, 0].set_ylabel('Reward')

# (0,1) Mean Q-value over training
axes[0, 1].set_title('Mean Q-Value')
axes[0, 1].set_xlabel('Episode')
axes[0, 1].set_ylabel('Q-Value')

# (0,2) Replay buffer size
axes[0, 2].set_title('Replay Buffer Size')
axes[0, 2].set_xlabel('Episode')
axes[0, 2].set_ylabel('Transitions')

# (1,0) Epsilon over time
axes[1, 0].set_title('Epsilon Schedule')
axes[1, 0].set_xlabel('Episode')
axes[1, 0].set_ylabel('Epsilon')

# (1,1) Loss over training
axes[1, 1].set_title('DQN Loss (smoothed)')
axes[1, 1].set_xlabel('Update Step')
axes[1, 1].set_ylabel('Loss')

# (1,2) Episode length
axes[1, 2].set_title('Episode Length')
axes[1, 2].set_xlabel('Episode')
axes[1, 2].set_ylabel('Steps')

plt.suptitle('LunarLander-v2: Double DQN Training Metrics', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Ablation Study Results
#
# Compare all configurations on LunarLander-v2.

# %%
# TODO: Load ablation results and display as table + plot

# Table format
ablation_configs = [
    'Full Double DQN',
    'DQN (no Double)',
    'No target network',
    'No replay + no target',
    'Buffer size = 1000',
    'Buffer size = 100000',
]

# Placeholder bar chart
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

# TODO: Replace with actual results
# avg_rewards = [results[c].moving_average(100) for c in ablation_configs]
# bars = ax.barh(ablation_configs, avg_rewards, color='#3498db')
# ax.set_xlabel('Avg Reward (last 100 episodes)')
# ax.set_title('LunarLander-v2 Ablation Study')

plt.tight_layout()
plt.show()
