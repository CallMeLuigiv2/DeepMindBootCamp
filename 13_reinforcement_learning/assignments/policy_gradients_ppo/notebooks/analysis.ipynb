# %% [markdown]
# # Policy Gradients & PPO Analysis Notebook
#
# Visualize training results, compare methods, and analyze gradient variance.
#
# ## Contents
# 1. Method Comparison: REINFORCE vs Baseline vs A2C vs PPO
# 2. Gradient Variance Analysis
# 3. PPO Training Metrics Dashboard
# 4. Entropy Coefficient Analysis
# 5. Sample Efficiency Comparison

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import sys
sys.path.append('..')

from utils import EpisodeTracker, compute_explained_variance

# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## 1. Method Comparison (5 seeds each)
#
# Plot mean +/- std reward curves for all four methods on CartPole-v1.
# X-axis: total environment timesteps. Y-axis: rolling average reward.

# %%
# TODO: Load comparison results
# results = torch.load('logs/method_comparison.pt')

fig, ax = plt.subplots(1, 1, figsize=(14, 7))

methods = ['REINFORCE', 'REINFORCE + Baseline', 'A2C', 'PPO']
colors = ['#e74c3c', '#f39c12', '#2ecc71', '#3498db']

# TODO: For each method, compute mean and std across seeds
# for name, color in zip(methods, colors):
#     seed_rewards = [tracker.get_smoothed_rewards(50) for tracker in results[name]]
#     # Align by timesteps and compute mean/std
#     mean_reward = np.mean(seed_rewards, axis=0)
#     std_reward = np.std(seed_rewards, axis=0)
#     ax.plot(mean_reward, label=name, color=color)
#     ax.fill_between(range(len(mean_reward)),
#                     mean_reward - std_reward,
#                     mean_reward + std_reward,
#                     alpha=0.15, color=color)

ax.set_xlabel('Episode')
ax.set_ylabel('Reward (smoothed, window=50)')
ax.set_title('CartPole-v1: Policy Gradient Method Comparison')
ax.legend(loc='lower right')
ax.axhline(y=475, color='gray', linestyle='--', alpha=0.5, label='Solved')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Gradient Variance Analysis
#
# Compare gradient variance between REINFORCE and REINFORCE+Baseline.
# The baseline should significantly reduce variance without changing the expected gradient.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# TODO: Load gradient variance data from evaluate.py

# Left: histogram of gradient norms
# axes[0].hist(reinforce_grad_norms, alpha=0.7, label='REINFORCE', color='#e74c3c')
# axes[0].hist(baseline_grad_norms, alpha=0.7, label='+ Baseline', color='#2ecc71')
# axes[0].set_xlabel('Gradient Norm')
# axes[0].set_ylabel('Count')
# axes[0].set_title('Distribution of Gradient Norms')
# axes[0].legend()

# Right: gradient norm over episodes
# axes[1].plot(reinforce_grad_norms, label='REINFORCE', color='#e74c3c', alpha=0.7)
# axes[1].plot(baseline_grad_norms, label='+ Baseline', color='#2ecc71', alpha=0.7)
# axes[1].set_xlabel('Episode')
# axes[1].set_ylabel('Gradient Norm')
# axes[1].set_title('Gradient Norm Over Training')
# axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. PPO Training Metrics Dashboard
#
# Policy loss, value loss, entropy, clip fraction, and explained variance.

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# TODO: Load PPO training metrics

titles = [
    'Episode Reward', 'Policy Loss', 'Value Loss',
    'Policy Entropy', 'Clip Fraction', 'Explained Variance'
]
ylabels = [
    'Reward', 'Loss', 'Loss',
    'Entropy', 'Fraction', 'EV'
]

for idx, (ax, title, ylabel) in enumerate(zip(axes.flat, titles, ylabels)):
    ax.set_title(title)
    ax.set_xlabel('Update')
    ax.set_ylabel(ylabel)

plt.suptitle('PPO Training Dashboard', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. A2C Entropy Coefficient Analysis
#
# Compare entropy_coeff = 0.0, 0.01, 0.1 on CartPole-v1.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

entropy_coeffs = [0.0, 0.01, 0.1]
colors = ['#e74c3c', '#2ecc71', '#3498db']

# TODO: Load results for each entropy coefficient

# Left: reward curves
axes[0].set_xlabel('Episode')
axes[0].set_ylabel('Reward')
axes[0].set_title('A2C: Effect of Entropy Coefficient on Reward')
# axes[0].legend()

# Right: policy entropy over training
axes[1].set_xlabel('Episode')
axes[1].set_ylabel('Policy Entropy')
axes[1].set_title('A2C: Policy Entropy Over Training')
# axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Sample Efficiency Comparison
#
# Compare methods by number of environment timesteps to reach average reward of 400.

# %%
# TODO: Compute timesteps-to-solve for each method

methods = ['REINFORCE', 'REINFORCE + Baseline', 'A2C', 'PPO']
# timesteps_to_solve = [...]

fig, ax = plt.subplots(1, 1, figsize=(10, 5))

# TODO: Create bar chart
# bars = ax.barh(methods, timesteps_to_solve, color=['#e74c3c', '#f39c12', '#2ecc71', '#3498db'])
# ax.set_xlabel('Environment Timesteps to Reach Avg Reward 400')
# ax.set_title('Sample Efficiency Comparison')

plt.tight_layout()
plt.show()
