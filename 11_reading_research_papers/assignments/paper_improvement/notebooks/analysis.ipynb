# %% [markdown]
# # Paper Improvement - Analysis
#
# 1. Hypothesis documentation
# 2. A/B comparison: training curves
# 3. Statistical comparison
# 4. Ablation study
# 5. Research note drafting

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import matplotlib.pyplot as plt

from utils import statistical_comparison, print_comparison_report, HypothesisTracker

# %% [markdown]
# ## Hypothesis

# %%
# Document your hypothesis BEFORE running experiments
hyp = HypothesisTracker(
    observation="[What weakness did you observe?]",
    proposed_change="[What specific modification will you make?]",
    expected_effect="[What do you predict will happen and why?]",
    test_method="[What experiment will confirm or refute?]",
    success_criterion="[How will you know if it worked?]",
)
hyp.save('hypothesis.md')
print('Hypothesis saved.')

# %% [markdown]
# ## A/B Comparison Results

# %%
# TODO: Load A/B comparison results and plot training curves
# TODO: Run statistical_comparison and print_comparison_report

# %% [markdown]
# ## Ablation Study

# %%
# TODO: Plot ablation results
