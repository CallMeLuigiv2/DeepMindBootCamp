# %% [markdown]
# # Paper Reproduction - Analysis
#
# 1. Implementation decisions and ambiguities
# 2. Training curves comparison
# 3. Results comparison table (paper vs ours)
# 4. Ablation study results

# %%
import sys
sys.path.insert(0, '..')

import json
import matplotlib.pyplot as plt
import numpy as np

from utils import ExperimentLogger, compare_results

# %% [markdown]
# ## Training Curves

# %%
# TODO: Load experiment results and plot training curves
# Compare: ResNet vs PlainNet at different depths

# %% [markdown]
# ## Results Comparison

# %%
# TODO: Create comparison table: paper's numbers vs our reproduction
# Include mean +/- std across seeds

# %% [markdown]
# ## Ablation Study

# %%
# TODO: Visualize ablation results
