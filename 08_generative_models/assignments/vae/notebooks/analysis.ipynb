# %% [markdown]
# # Variational Autoencoder - Analysis Notebook
#
# ## Contents
# 1. Train and evaluate the standard VAE
# 2. Latent space visualization and interpretation
# 3. Latent space interpolation
# 4. Beta-VAE experiments
# 5. Conditional VAE
# 6. Written analysis

# %%
import sys
sys.path.append('..')

import torch
import numpy as np
import matplotlib.pyplot as plt

from data import get_mnist_dataloaders, flatten_batch, unflatten_batch
from model import VAE, ConditionalVAE, vae_loss
from utils import (
    set_seed, plot_sample_grid, plot_reconstructions,
    plot_latent_space, plot_latent_grid_decode, plot_interpolation,
)

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')

# %% [markdown]
# ## 1. Standard VAE

# %%
# TODO: Load or train the standard VAE (latent_dim=2)
# TODO: Show reconstructions vs originals
# TODO: Generate a grid of 100 random samples

# %% [markdown]
# ## 2. Latent Space Visualization

# %%
# TODO: Encode test set, plot 2D scatter colored by digit class
# TODO: Decode a 20x20 grid covering [-3, 3] x [-3, 3]
# Questions to answer:
# - Are digit classes clustered and separated?
# - Is the overall distribution roughly Gaussian?
# - Which digits overlap? Does this match your intuition?

# %% [markdown]
# ## 3. Latent Space Interpolation

# %%
# TODO: Linear interpolation between pairs of digits (e.g., 3 -> 7)
# TODO: Random walk in latent space

# %% [markdown]
# ## 4. Beta-VAE Experiments

# %%
# TODO: Train VAEs with beta = [0.1, 0.5, 1.0, 2.0, 5.0, 10.0]
# TODO: For each, show:
#   - Generated samples
#   - Latent space plot
#   - Final recon_loss and kl_loss
# TODO: Create a beta vs quality table

# %% [markdown]
# ## 5. Conditional VAE

# %%
# TODO: Train CVAE
# TODO: Generate 10x10 grid (10 samples per digit class)
# TODO: Conditional interpolation (style variations within a class)

# %% [markdown]
# ## 6. Written Analysis
#
# 1. Explain the ELBO in your own words. What does each term encourage?
# 2. Describe what you observe in the latent space. Why are some digits closer?
# 3. Analyze the beta-VAE results. What is the practical tradeoff?
# 4. Compare the standard VAE and conditional VAE. What does conditioning buy you?
