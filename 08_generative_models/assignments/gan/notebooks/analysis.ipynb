# %% [markdown]
# # GAN - Analysis Notebook
#
# ## Contents
# 1. Basic GAN on MNIST
# 2. Instability Experiments (mode collapse, discriminator dominance)
# 3. DCGAN Training Progression
# 4. WGAN-GP Comparison
# 5. FID Evaluation
# 6. Written Analysis

# %%
import sys
sys.path.append('..')

import torch
import numpy as np
import matplotlib.pyplot as plt
from torchvision.utils import make_grid

from model import BasicGenerator, DCGANGenerator
from utils import set_seed, plot_d_scores, plot_training_progression

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 6)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')

# %% [markdown]
# ## 1. Basic GAN Results

# %%
# TODO: Load trained basic GAN
# TODO: Display sample grids from training progression
# TODO: Plot G and D loss curves

# %% [markdown]
# ## 2. Instability Experiments
#
# ### 2.1 Mode Collapse
# High LR for G (1e-3), low LR for D (1e-5).

# %%
# TODO: Generate 1000 samples from the mode-collapsed model
# TODO: Inspect which digit classes are represented
# TODO: Plot D(G(z)) over training

# %% [markdown]
# ### 2.2 Discriminator Dominance
# Train D for 5 steps per G step, high LR for D.

# %%
# TODO: Plot D(G(z)) -- should approach 0
# TODO: Show that generator loss plateaus

# %% [markdown]
# ## 3. DCGAN Training Progression

# %%
# TODO: Show sample grids at epochs 1, 5, 10, 25, 50

# %% [markdown]
# ## 4. Standard GAN vs WGAN-GP

# %%
# TODO: Side-by-side sample comparison at same epoch
# TODO: Compare loss curves
# TODO: Compare training stability

# %% [markdown]
# ## 5. FID Scores

# %%
# TODO: Compute FID for DCGAN and WGAN-GP at multiple epochs
# TODO: Plot FID vs epoch for both

# %% [markdown]
# ## 6. Written Analysis
#
# 1. Describe the training dynamics you observed.
# 2. Explain mode collapse in your own words, with evidence.
# 3. Compare standard GAN loss and Wasserstein loss.
# 4. What FID scores did you achieve? How do they compare to benchmarks?
